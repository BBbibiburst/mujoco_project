# %%
"""
自定义抓取环境构建模块.

该模块集成了机械臂与机械手模型，并在此基础上构建了一个包含动态物体、光照及自定义相机的
仿真场景。模块通过 Matplotlib 实现了相机视角的实时渲染展示，并提供了演示用的控制逻辑。
"""

import mujoco
from mujoco import mjtGeom, mjtJoint
from robot_arm_system import get_combined_spec
from typing import Tuple, Any, Optional
import numpy as np
import matplotlib.pyplot as plt

# 内部模块导入
from hand_arm_controller import HandArmController

# ====================== 仿真常量配置 ======================
CAM_WIDTH = 320
CAM_HEIGHT = 240
TARGET_POS = [0.4, 0.0, 0.025]  # 目标物体初始位置


spec = get_combined_spec(
        rot_xyz_deg=(-90, 0, 0),
        attach_point_name="right_hand"
    )
worldbody = spec.worldbody
# Out:
# [SpecBuilder] 加载机械臂: rm75b.xml
# [SpecBuilder] 加载机械手: inspirehand.xml
# [SpecBuilder] 成功挂载: 'inspirehand_hand_root' 到 'right_hand'
# [SpecBuilder] 姿态设定完成: Euler=(-90, 0, 0) deg

# %%
# 列出worldbody下的所有方法
print(f"[EnvBuilder] worldbody 可用方法: {dir(worldbody)}")
print(f"[EnvBuilder] worldbody 下的所有 body: {[body.name for body in worldbody.bodies]}")
root_body = worldbody.bodies[0]  # 获取 root body
print(f"[EnvBuilder] root body下的所有 body: {[body.name for body in root_body.bodies]}")
# Out:
# [EnvBuilder] worldbody 可用方法: ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_pybind11_conduit_v1_', 'add_body', 'add_camera', 'add_frame', 'add_freejoint', 'add_geom', 'add_joint', 'add_light', 'add_site', 'alt', 'attach_frame', 'bodies', 'cameras', 'childclass', 'classname', 'compiler', 'explicitinertial', 'find_all', 'find_child', 'first_body', 'first_camera', 'first_frame', 'first_geom', 'first_joint', 'first_light', 'first_site', 'frame', 'frames', 'fullinertia', 'geoms', 'gravcomp', 'ialt', 'id', 'inertia', 'info', 'ipos', 'iquat', 'joints', 'lights', 'mass', 'mocap', 'name', 'next_body', 'next_camera', 'next_frame', 'next_geom', 'next_joint', 'next_light', 'next_site', 'parent', 'plugin', 'pos', 'quat', 'set_frame', 'signature', 'sites', 'sleep', 'to_frame', 'userdata']
# [EnvBuilder] worldbody 下的所有 body: ['root']
# [EnvBuilder] root body下的所有 body: ['Link1']
