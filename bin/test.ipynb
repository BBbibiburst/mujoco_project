# %%
DEFAULT_GRASP_PHYSICS = PhysicsConfig(
    arm_defaults=JointPhysicsConfig(
        # stiffness=100.0,    # 高刚度，抵抗重力下垂
        damping=10.0,        # 保持原值
        frictionloss=1,      # 保持原值  
        armature=0.01,       # 保持原值
    ),
    hand_defaults=JointPhysicsConfig(
        # stiffness=1.0,     # 适中刚度，保持手指自然张开
        damping=0.01,        # 保持全局默认
        armature=0.01,
        frictionloss=0.01,
    ),
    per_joint_overrides={
        # thumb_rotate_act_push_j 在XML中已单独设为10.0
        # 如需代码覆盖，注意前缀是 inspirehand_thumb_rotate_act_push_j
        "thumb_rotate_act_push_j": JointPhysicsConfig(damping=10.0),
    }
)

# %%
import cv2
import numpy as np

img = np.zeros((200, 200, 3), dtype=np.uint8)
cv2.imshow("Test", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
